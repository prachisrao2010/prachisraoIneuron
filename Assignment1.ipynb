# %%
#Assiggment no 1 
#1. Write a program which will find all such numbers which are divisible by 7 but are not a
#multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed
#in a comma-separated sequence on a single line.

import os
import datetime
#The % symbol in Python is called the Modulo Operator. It returns the remainder of dividing the left hand operand by right hand operand. It's used to get the remainder of a division problem
count=0
for seq in range(2000-1, 3200+1):
    v1= seq % 7
    v2= seq % 5
    if v1==0 and v2 >0:
      print("No which is divisible by 7 but not multiple of 5 is ..>",seq)
      count= count+ 1
print("total numbers found are= ",count)
# Out:
# No which is divisible by 7 but not multiple of 5 is ..> 2002
# No which is divisible by 7 but not multiple of 5 is ..> 2009
# No which is divisible by 7 but not multiple of 5 is ..> 2016
# No which is divisible by 7 but not multiple of 5 is ..> 2023
# No which is divisible by 7 but not multiple of 5 is ..> 2037
# No which is divisible by 7 but not multiple of 5 is ..> 2044
# No which is divisible by 7 but not multiple of 5 is ..> 2051
# No which is divisible by 7 but not multiple of 5 is ..> 2058
# No which is divisible by 7 but not multiple of 5 is ..> 2072
# No which is divisible by 7 but not multiple of 5 is ..> 2079
# No which is divisible by 7 but not multiple of 5 is ..> 2086
# No which is divisible by 7 but not multiple of 5 is ..> 2093
# No which is divisible by 7 but not multiple of 5 is ..> 2107
# No which is divisible by 7 but not multiple of 5 is ..> 2114
# No which is divisible by 7 but not multiple of 5 is ..> 2121
# No which is divisible by 7 but not multiple of 5 is ..> 2128
# No which is divisible by 7 but not multiple of 5 is ..> 2142
# No which is divisible by 7 but not multiple of 5 is ..> 2149
# No which is divisible by 7 but not multiple of 5 is ..> 2156
# No which is divisible by 7 but not multiple of 5 is ..> 2163
# No which is divisible by 7 but not multiple of 5 is ..> 2177
# No which is divisible by 7 but not multiple of 5 is ..> 2184
# No which is divisible by 7 but not multiple of 5 is ..> 2191
# No which is divisible by 7 but not multiple of 5 is ..> 2198
# No which is divisible by 7 but not multiple of 5 is ..> 2212
# No which is divisible by 7 but not multiple of 5 is ..> 2219
# No which is divisible by 7 but not multiple of 5 is ..> 2226
# No which is divisible by 7 but not multiple of 5 is ..> 2233
# No which is divisible by 7 but not multiple of 5 is ..> 2247
# No which is divisible by 7 but not multiple of 5 is ..> 2254
# No which is divisible by 7 but not multiple of 5 is ..> 2261
# No which is divisible by 7 but not multiple of 5 is ..> 2268
# No which is divisible by 7 but not multiple of 5 is ..> 2282
# No which is divisible by 7 but not multiple of 5 is ..> 2289
# No which is divisible by 7 but not multiple of 5 is ..> 2296
# No which is divisible by 7 but not multiple of 5 is ..> 2303
# No which is divisible by 7 but not multiple of 5 is ..> 2317
# No which is divisible by 7 but not multiple of 5 is ..> 2324
# No which is divisible by 7 but not multiple of 5 is ..> 2331
# No which is divisible by 7 but not multiple of 5 is ..> 2338
# No which is divisible by 7 but not multiple of 5 is ..> 2352
# No which is divisible by 7 but not multiple of 5 is ..> 2359
# No which is divisible by 7 but not multiple of 5 is ..> 2366
# No which is divisible by 7 but not multiple of 5 is ..> 2373
# No which is divisible by 7 but not multiple of 5 is ..> 2387
# No which is divisible by 7 but not multiple of 5 is ..> 2394
# No which is divisible by 7 but not multiple of 5 is ..> 2401
# No which is divisible by 7 but not multiple of 5 is ..> 2408
# No which is divisible by 7 but not multiple of 5 is ..> 2422
# No which is divisible by 7 but not multiple of 5 is ..> 2429
# No which is divisible by 7 but not multiple of 5 is ..> 2436
# No which is divisible by 7 but not multiple of 5 is ..> 2443
# No which is divisible by 7 but not multiple of 5 is ..> 2457
# No which is divisible by 7 but not multiple of 5 is ..> 2464
# No which is divisible by 7 but not multiple of 5 is ..> 2471
# No which is divisible by 7 but not multiple of 5 is ..> 2478
# No which is divisible by 7 but not multiple of 5 is ..> 2492
# No which is divisible by 7 but not multiple of 5 is ..> 2499
# No which is divisible by 7 but not multiple of 5 is ..> 2506
# No which is divisible by 7 but not multiple of 5 is ..> 2513
# No which is divisible by 7 but not multiple of 5 is ..> 2527
# No which is divisible by 7 but not multiple of 5 is ..> 2534
# No which is divisible by 7 but not multiple of 5 is ..> 2541
# No which is divisible by 7 but not multiple of 5 is ..> 2548
# No which is divisible by 7 but not multiple of 5 is ..> 2562
# No which is divisible by 7 but not multiple of 5 is ..> 2569
# No which is divisible by 7 but not multiple of 5 is ..> 2576
# No which is divisible by 7 but not multiple of 5 is ..> 2583
# No which is divisible by 7 but not multiple of 5 is ..> 2597
# No which is divisible by 7 but not multiple of 5 is ..> 2604
# No which is divisible by 7 but not multiple of 5 is ..> 2611
# No which is divisible by 7 but not multiple of 5 is ..> 2618
# No which is divisible by 7 but not multiple of 5 is ..> 2632
# No which is divisible by 7 but not multiple of 5 is ..> 2639
# No which is divisible by 7 but not multiple of 5 is ..> 2646
# No which is divisible by 7 but not multiple of 5 is ..> 2653
# No which is divisible by 7 but not multiple of 5 is ..> 2667
# No which is divisible by 7 but not multiple of 5 is ..> 2674
# No which is divisible by 7 but not multiple of 5 is ..> 2681
# No which is divisible by 7 but not multiple of 5 is ..> 2688
# No which is divisible by 7 but not multiple of 5 is ..> 2702
# No which is divisible by 7 but not multiple of 5 is ..> 2709
# No which is divisible by 7 but not multiple of 5 is ..> 2716
# No which is divisible by 7 but not multiple of 5 is ..> 2723
# No which is divisible by 7 but not multiple of 5 is ..> 2737
# No which is divisible by 7 but not multiple of 5 is ..> 2744
# No which is divisible by 7 but not multiple of 5 is ..> 2751
# No which is divisible by 7 but not multiple of 5 is ..> 2758
# No which is divisible by 7 but not multiple of 5 is ..> 2772
# No which is divisible by 7 but not multiple of 5 is ..> 2779
# No which is divisible by 7 but not multiple of 5 is ..> 2786
# No which is divisible by 7 but not multiple of 5 is ..> 2793
# No which is divisible by 7 but not multiple of 5 is ..> 2807
# No which is divisible by 7 but not multiple of 5 is ..> 2814
# No which is divisible by 7 but not multiple of 5 is ..> 2821
# No which is divisible by 7 but not multiple of 5 is ..> 2828
# No which is divisible by 7 but not multiple of 5 is ..> 2842
# No which is divisible by 7 but not multiple of 5 is ..> 2849
# No which is divisible by 7 but not multiple of 5 is ..> 2856
# No which is divisible by 7 but not multiple of 5 is ..> 2863
# No which is divisible by 7 but not multiple of 5 is ..> 2877
# No which is divisible by 7 but not multiple of 5 is ..> 2884
# No which is divisible by 7 but not multiple of 5 is ..> 2891
# No which is divisible by 7 but not multiple of 5 is ..> 2898
# No which is divisible by 7 but not multiple of 5 is ..> 2912
# No which is divisible by 7 but not multiple of 5 is ..> 2919
# No which is divisible by 7 but not multiple of 5 is ..> 2926
# No which is divisible by 7 but not multiple of 5 is ..> 2933
# No which is divisible by 7 but not multiple of 5 is ..> 2947
# No which is divisible by 7 but not multiple of 5 is ..> 2954
# No which is divisible by 7 but not multiple of 5 is ..> 2961
# No which is divisible by 7 but not multiple of 5 is ..> 2968
# No which is divisible by 7 but not multiple of 5 is ..> 2982
# No which is divisible by 7 but not multiple of 5 is ..> 2989
# No which is divisible by 7 but not multiple of 5 is ..> 2996
# No which is divisible by 7 but not multiple of 5 is ..> 3003
# No which is divisible by 7 but not multiple of 5 is ..> 3017
# No which is divisible by 7 but not multiple of 5 is ..> 3024
# No which is divisible by 7 but not multiple of 5 is ..> 3031
# No which is divisible by 7 but not multiple of 5 is ..> 3038
# No which is divisible by 7 but not multiple of 5 is ..> 3052
# No which is divisible by 7 but not multiple of 5 is ..> 3059
# No which is divisible by 7 but not multiple of 5 is ..> 3066
# No which is divisible by 7 but not multiple of 5 is ..> 3073
# No which is divisible by 7 but not multiple of 5 is ..> 3087
# No which is divisible by 7 but not multiple of 5 is ..> 3094
# No which is divisible by 7 but not multiple of 5 is ..> 3101
# No which is divisible by 7 but not multiple of 5 is ..> 3108
# No which is divisible by 7 but not multiple of 5 is ..> 3122
# No which is divisible by 7 but not multiple of 5 is ..> 3129
# No which is divisible by 7 but not multiple of 5 is ..> 3136
# No which is divisible by 7 but not multiple of 5 is ..> 3143
# No which is divisible by 7 but not multiple of 5 is ..> 3157
# No which is divisible by 7 but not multiple of 5 is ..> 3164
# No which is divisible by 7 but not multiple of 5 is ..> 3171
# No which is divisible by 7 but not multiple of 5 is ..> 3178
# No which is divisible by 7 but not multiple of 5 is ..> 3192
# No which is divisible by 7 but not multiple of 5 is ..> 3199
# total numbers found are=  138
